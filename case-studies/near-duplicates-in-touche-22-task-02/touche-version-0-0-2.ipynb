# %% [markdown]
# # Touché 2022: Collection Version 0.0.2 for Task 2

# %% [markdown]
# We discussed the following improvements of version 0.0.2 over 0.0.1:
#
# - Remove duplicated Ids (they were in version 0.0.1 due to some pooling problem)
# - Remove passages that are too short (less than 10 terms)
#   - concerns 5083 of the 1222231 passages
# - Remove passages that are too long (more than 1024 terms)
#   - concerns 584 of the 1222231 passages
# - Remove near-duplicate passages
#   - concerns 348512 of the 1222231 passages
# - Combine everything into a single file

# %%
def all_lines(file_name):
    import json
    from tqdm import tqdm
    
    with open('/mnt/ceph/storage/data-in-progress/data-research/arguana/touche-shared-tasks/data/2022-task2/data-cleaning/' + file_name) as f:
        for i in tqdm(f):
            try:
                yield json.loads(i)
            except:
                pass

# %%
too_short = []
too_long = []
docs = {}

for year in ['2020', '2021']:
    for i in all_lines(year + '-task2-passages-of-top100-docs.jsonl'):
        docs[i['id']] = i
        
        length = len(i['fullyCanonicalizedContent'].split())
        
        if length > 1024:
            too_long += [i['id']]
        if length < 10:
            too_short += [i['id']]
            
too_short = set(too_short)
too_long = set(too_long)
# Out:
# 595428it [01:58, 5005.52it/s]
# 691551it [02:17, 5013.84it/s]

# %%
len(docs)
# Out:
# 1222231

# %%
len(too_short)
# Out:
# 5083

# %%
len(too_long)
# Out:
# 584

# %%
duplicates = []

for year in ['2020', '2021']:
    for i in all_lines('s3-scores-' + year + '-task2-passages-of-top100-docs.jsonl'):
        firstId = i['idPair']['left']
        secondId = i['idPair']['right']
        
        if firstId == secondId:
            continue
            
        if firstId > secondId:
            raise ValueError('')
        
        # this near-duplicate threshold is from previous studies
        if i['s3Score'] > 0.82:
            duplicates += [secondId]

duplicates = set(duplicates)
# Out:
# 12197648it [07:09, 28428.27it/s]
# 11373094it [07:53, 24024.03it/s]

# %%
print(len(duplicates))
# Out:
# 348512

# %% [markdown]
# # Some example duplicates

# %%
#clueweb12-0915wb-42-00127___124 , clueweb12-0915wb-93-17218___124 --> 1.0

print(docs['clueweb12-0915wb-42-00127___124']['content'])
print('\n\n')
print(docs['clueweb12-0915wb-93-17218___124']['content'])
# Out:
# Where the market has done an efficient job in flushing out Chinese RTOs and other equities with unreliable accounting, the notion of hiring a team of lawyers to prop of a company with questionable financials, reconciled by non existent auditing firm is a dangerous blueprint for other Chinese companies to inflate their stock while management could possibly be selling stock into a bidding market. Chinese nationals in management positions, insulated as they are from any enforcement of US securities law can easily orchestrate the whole process. Therefore the SEC is a gatekeeper on a set of market integrity concerns which stretch far beyond the current Harbin drama. Proof that Tianfu Yang has NO INTENTION of Concluding the Proposed $24 Buyout of Harbin Electric It's really quite simple. If Tianfu Yang wanted to buy Harbin Electric he would have taken a different path. He knew Simo's cash couldn't be reconciled. He knew his gross margins from his antiquated factories couldn't possibly be double or triple any of his competitors. He knew the sales to disclosed major customers were false. More than anyone, he knows that the company keeps consuming cash, despite the profitable financial statements and projections.
#
#
#
# Where the market has done an efficient job in flushing out Chinese RTOs and other equities with unreliable accounting, the notion of hiring a team of lawyers to prop of a company with questionable financials, reconciled by non existent auditing firm is a dangerous blueprint for other Chinese companies to inflate their stock while management could possibly be selling stock into a bidding market. Chinese nationals in management positions, insulated as they are from any enforcement of US securities law can easily orchestrate the whole process. Therefore the SEC is a gatekeeper on a set of market integrity concerns which stretch far beyond the current Harbin drama. Proof that Tianfu Yang has NO INTENTION of Concluding the Proposed $24 Buyout of Harbin Electric It's really quite simple. If Tianfu Yang wanted to buy Harbin Electric he would have taken a different path. He knew Simo's cash couldn't be reconciled. He knew his gross margins from his antiquated factories couldn't possibly be double or triple any of his competitors. He knew the sales to disclosed major customers were false. More than anyone, he knows that the company keeps consuming cash, despite the profitable financial statements and projections.

# %%
#clueweb12-0803wb-25-35631___2 , clueweb12-0808wb-93-02306___2 --> 0.9166666666666666

print(docs['clueweb12-0803wb-25-35631___2']['content'])
print('\n\n')
print(docs['clueweb12-0808wb-93-02306___2']['content'])
# Out:
# Local Business Search TrueLocal.com.au Business: Type Name In Printer Friendly Text size + - Your News Save the environment and money with our tips for a green Christmas Environment 20 Dec 11 @ 02:21pm by Nicole Has your food waste expanded over Christmas? Would you like to know how you can minimise your carbon footprint over the holiday season? The Nature Conservation Council of NSW offers practical advice and tips to help reduce the environmental impact of your festive season. Food and drink Plan all Christmas meals in advance and use a shopping list to ensure that you only purchase what is necessary. This will not only help the environment, but will also save money, time and improve nutrition. Buy local and organic food produce which is fresh, supports local farmers, and reduces food miles and transport emissions.
#
#
#
# Local Business Search TrueLocal.com.au Business: Type Name In Printer Friendly Text size + - Your News Save the environment and money with our tips for a green Christmas Environment 20 Dec 11 @ 02:32pm by Nicole Has your food waste expanded over Christmas? Would you like to know how you can minimise your carbon footprint over the holiday season? The Nature Conservation Council of NSW offers practical advice and tips to help reduce the environmental impact of your festive season. Food and drink Plan all Christmas meals in advance and use a shopping list to ensure that you only purchase what is necessary. This will not only help the environment, but will also save money, time and improve nutrition. Buy local and organic food produce which is fresh, supports local farmers, and reduces food miles and transport emissions.

# %%
#clueweb12-0803wb-67-20451___7 , clueweb12-0805wb-36-03834___7 --> 0.847926267281106

print(docs['clueweb12-0803wb-67-20451___7']['content'])
print('\n\n')
print(docs['clueweb12-0805wb-36-03834___7']['content'])
# Out:
# Rather than mailing a card, send friends and family a virtual card instead. The festive season does not have to be a time of over consumption and waste. By planning ahead you can minimise your carbon footprint and encourage others around you to do the same. Photo: Marju Randmer Write the News! Know something we don't? Help set the local agenda by writing your own news stories. Write news About the author Writer: Nicole Articles Written: 49 Joined: 9 August 2011 Related Articles Save the environment and money with our tips for a green Christmas Has your food waste expanded over Christmas? Would you like to know how you can minimise your carbon... Add your Comment Your name: * Email address: * Postcode: Comment: *(max 1200 characters) Verify: (type word into box on right)
#
#
#
# Rather than mailing a card, send friends and family a virtual card instead. The festive season does not have to be a time of over consumption and waste. By planning ahead you can minimise your carbon footprint and encourage others around you to do the same. Photo: Marju Randmer Write the News! Know something we don't? Help set the local agenda by writing your own news stories. Write news About the author Writer: Nicole Articles Written: 49 Joined: 9 August 2011 Related Articles Save the environment and money with our tips for a green Christmas Has your food waste expanded over Christmas? Would you like to know how you can minimise your carbon... Helping Bring Back The Bush at Plough & Harrow Reserve On the last Sunday of each month since July this year a group of interested local residents have... Add your Comment Your name: * Email address: * Postcode: Comment: *(max 1200 characters) Verify: (type word into box on right)

# %% [markdown]
# # Verify too short or too long

# %%
docs[[i for i in too_short][0]]['content']
# Out:
# 'All Rights Reserved'

# %%
docs[[i for i in too_short][10]]['content']
# Out:
# 'Author Name: Site contents ©2005 - 2010 Linux Install. Net'

# %%
docs[[i for i in too_long][0]]['content']
# Out:
# 'March 2009 February 2009 January 2009 December 2008 November 2008 October 2008 September 2008 August 2008 July 2008 June 2008 May 2008 April 2008 March 2008 February 2008 January 2008 December 2007 November 2007 October 2007 September 2007 August 2007 July 2007 June 2007 May 2007 April 2007 March 2007 February 2007 January 2007 December 2006 November 2006 October 2006 September 2006 August 2006 July 2006 June 2006 May 2006 April 2006 March 2006 November 2005 October 2005 Categories Select Category “Accidents” “Atlantic Yards” “Gridlock” Sam Schwartz “Sustainable Streets” 2009 Transportation Bill 9th Avenue Renaissance 9th Street Road Diet Aaron Naparstek AARP AASHTO Ad Nauseam Adolfo Carrion Adrian Benepe Adriano Espaillat Air Quality Al Gore Alan Gerson Albany Reform Alex Marshall Allerton Amanda Burden Amsterdam Amtrak Andrew Cuomo Andrew Hevesi Andrew Lanza Andy Wiley-Schwartz Angela Glover Blackwell Anthony Weiner April Fool’s Day APTA Astoria Astrid Glynn Athens Athletes and Celebrities Atlanta Australia Baghdad Baltimore Bangkok Barack Obama Barbara Boxer Barcelona Battery Park City Bay Ridge Bayside Bed-Stuy Beijing Bensonhurst Berkeley Berlin Bertrand Delanoë Bestocracy Bettina Damiani Bicycle Infrastructure Bicycle Parking Bicycle Safety Bicycling Bike Boulevards Bike Boxes Bike Lanes Bike Sharing Bike Snob Bike Theft Bill de Blasio Block Parties Bob Yaro Boerum Hill Bogotá Bollards Boris Johnson Borough Park Boston Boulder Brad Lander Brazil Brian Kavanagh Brian Ketcham Bridge Tolls Brighton Beach Brooklyn Brooklyn Bridge Brooklyn Greenway Initiative Brooklyn Greenway Initiative Brooklyn Heights Brooklyn Public Library Brooklyn-Queens Expressway Brownsville Bruce Schaller Brussels Bus Bulbs Bus Rapid Transit Buses Bushwick Campaign Contributions Campaign for New York’s Future Canarsie Caption Contest Car Culture Car Dependence Car-Free Parks Car-Free Streets Car-Sharing Carbon Tax Carl Heastie Carl Kruger Carly Clark Carnage Carolyn Konheim Carolyn Maloney Carroll Gardens Cartoon Tuesday Celebrity Cyclists Central Park Chad Marlow Charles Komanoff Charles Rangel Charles Schumer CHEKPEDS Chelsea Chicago Chicanes China Chinatown Chris Christie Chris Dodd Chris Ward Christine Berthet Christine Quinn Chuck Schumer Ciclovía Citizens Budget Commission Citizens for NYC City Council CityRacks CityStreets Civil Rights Clarence Eckerson Cleveland Climate Bill Climate Change Clinton Hill Co-Op City Cobble Hill Community Board Reform Community Boards Community Organizations COMMUTE Commuting Complete Streets Coney Island Confrontations Congestion Pricing Congress for the New Urbanism Contraflow Bike Lanes Copenhagen Corporate Buildings & Bike Parking Critical Mass Crown Heights Curitiba Cy Vance Damien Newton Dan Burden Dan Doctoroff Dan Garodnick Dani Simons Daniel Dromm Daniel O’Donnell Daniel Squadron David Bragdon David Burwell David Byrne David Engwicht David Gantt David Greenfield David Paterson David Weprin David Yassky DDC Dean Skelos Deborah Glick Denmark Denny Farrell Denver Department of City Planning Department of Education Department of Environmental Protection Department of Health & Mental Hygiene Department of Parks & Recreation Dept. of Consumer Affairs Detroit Development Dick Gottfried Distracted Driving Dollar Vans Domenic Recchia Donald Shoup Doris Matsui DOT Dov Hikind Downtown Brooklyn Downtown Brooklyn Partnership Downtown Brooklyn Traffic Calming Project Drum Major Institute DUMBO Earl Blumenauer East Harlem East New York East River Greenway East River Park East Village Economic Development Corporation Economics Ed Rendell Ed Skyler Elderly & Disabled Elections Elizabeth Press Elizabeth Yeampierre Elliot “Lee” Sander Elliot Spitzer Emily Lloyd Eminent Domain Energy Enrique Peñalosa Environmental Defense Environmental Justice Environmental Review EPA Eric Adams Eric Britton Eric Schneiderman Eric Ulrich Ethan Kent Events Eyes on the Street Fare Hikes FDR Drive Federal Funding Federal Highway Administratio ...

# %%
docs[[i for i in too_long][10]]['content']
# Out:
# "Customer Service | RSS Feeds | International | About Runner's World | Advertising | Privacy Rights/Community Guidelines | Manage Email Preferences Rodale | Running Times | Bicycling | Men's Health | Women's Health | Prevention | Organic Gardening | Fitbie.com | Sitemap © 2012 Rodale Inc. pediatric prednisone for sinus problems prednisone facts homopathic replacement for prednisone prednisone for vestibular nueritis prednisone lupus side effects mental prednisone treatment for rheumatoid arthritis effects of prednisone copd prednisone weight gain calcinosis cutis dog prednisone dog prednisone side effect drug interaction prednisone difference between prednisone and dexamethasone bells palsy prednisone acyclovir prednisilone prednisone safe long term prednisone daily dosage weening off prednisone what is vet medicine prednisone prednisone and allergies prednisone 100mg prednisone and colds prednisone replacement high dose prednisone side effects prednisone 10 mg dosage prednisone transverse myelitis what type of pill is prednisone prednisone and adrenal glands prednisone used for hives disabe of prednisone prednisone and naproxen prednisone reducing side effects prednisone and menastration prednisone q4 doseing photo of prednisone tablet can you take prednisone and advil bladder control from prednisone can prednisone make someone homicidal prednisone and cold can prednisone stop menstrual flow prednisone palpitations prednisone with antibiotics in canines benedryl and prednisone prednisone medicine tapering off prednisone 2006 prednisone and diabetes and cataracts prednisone burst and tapers prednisone and menstral period prednisone treatment symptoms from tappering off prednisone tappering off prednisone prednisone hydrocodone drug interaction weaning a dog off prednisone rash on chest prednisone canine prednisone cushings target of prednisone absorption prednisone inhibited antacids prednisone and athletic performance canine incontinence and prednisone dementia and prednisone codeine and prednisone prednisone pulse prednisone mail pharmacy no prescription effects prednisone side warning beta glucan and prednisone american diabetic association prednisone side effects of prednisone with concussion drinking alcohol with prednisone prednisone in acute lymphoblastic leukemia prednisone tapering side effects prednisone 1mg order prednisone no prescription prednisone burst taper prednisone dosepack 10 mg what does prednisone do to you prednisone teenney prednisone onelook dictionary search counteracting prednisone side-effects decadron amount equal to prednisone prednisone response time rheumatoid arthritis flare up prednisone prednisone and leg cramps what is prednisone for prednisone and birth control alanine transferase prednisone prednisone for acne prednisone steroid side effects prednisone and neutrophils prednisone cause diabetes side effects of prednisone pictures prednisone tapering course fatty deposits from prednisone prednisone sinus infection excessive urination with prednisone in humans prednisone tablet non prescription prednisone apo prednisone 5mg prednisone prednisone what are the symptoms prednisone and liver enyzimes pediatric prednisone dosage prednisone restylane keyword prednisone and teen boards leukemia and prednisone prednisone and benedryl prednisone side affect side effects if prednisone cats hypertension prednisone teenneys prednisone and getting pregnant blood glucose prednisone prednisone side effects dosage prednisone tablets size bleomycin toxicity prednisone case reports prednisone side effects heart prednisone and lung nodule prednisone antibiotic copd does prednisone contain gluten itp prednisone dose pulse dose of prednisone prednisone and seizures peak effect of prednisone after administration prednisone congestive heart failure online pharmacy prednisone feline peripheral nerve disease prednisone prednisone dosepak and inhalers red face from prednisone prednisone side effects on felines what is ...

# %% [markdown]
# # Create Version 0.0.2 from 0.0.1 using the above information

# %%
ids_already_covered = set()

with open('/mnt/ceph/storage/data-in-progress/data-research/arguana/touche-shared-tasks/data/2022-task2/touche-task2-passages-version-002.jsonl', 'w') as out_file:
    import json
    for year in ['2020', '2021']:
        for i in all_lines('../../' + year + '-task2-passages-of-top100-docs.jsonl'):
            doc_id = i['id']
            if doc_id in ids_already_covered or doc_id in duplicates or doc_id in too_short or doc_id in too_long:
                continue
            
            ids_already_covered.add(doc_id)
            out_file.write(json.dumps(i) + '\n')
        

print(len(ids_already_covered))
# Out:
# 595432it [01:51, 5344.91it/s]
# 691551it [02:05, 5518.96it/s]
# 868655

# %%
# !gzip -c /mnt/ceph/storage/data-in-progress/data-research/arguana/touche-shared-tasks/data/2022-task2/touche-task2-passages-version-002.jsonl > /mnt/ceph/storage/data-in-progress/data-research/arguana/touche-shared-tasks/data/2022-task2/touche-task2-passages-version-002.jsonl.gz
